# %%
# %pip install networkx
# %pip install matplotlib
# Out:
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip3.11 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp311-cp311-macosx_11_0_arm64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 28.1 MB/s eta 0:00:0000:0100:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp311-cp311-macosx_11_0_arm64.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 14.6 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.4-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-macosx_11_0_arm64.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.3 MB/s eta 0:00:00
# Collecting numpy>=1.20
#   Downloading numpy-1.24.3-cp311-cp311-macosx_11_0_arm64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 24.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.0 in /Users/elizabethfrey/Library/Python/3.11/lib/python/site-packages (from matplotlib) (23.1)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp311-cp311-macosx_11_0_arm64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 25.7 MB/s eta 0:00:0000:0100:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /Users/elizabethfrey/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/elizabethfrey/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.4 kiwisolver-1.4.4 matplotlib-3.7.1 numpy-1.24.3 pillow-9.5.0 pyparsing-3.0.9
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip3.11 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx

G = nx.DiGraph()

G.add_node('A')
G.add_node('B')
G.add_node('C')

G.add_edge('A', 'B')
G.add_edge('B', 'C')
G.add_edge('C', 'A')

# %%
import matplotlib.pyplot as plt

nx.draw(G, with_labels=True, arrows=True)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
bfs = nx.bfs_edges(G, source='0')
dict(enumerate(nx.bfs_layers(G, [0, 4])))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/networkx/classes/digraph.py:899, in DiGraph.successors(self, n)
#     898 try:
# --> 899     return iter(self._succ[n])
#     900 except KeyError as err:
#
# KeyError: '0'
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In[13], line 2
#       1 bfs = nx.bfs_predecessors(G, source='0')
# ----> 2 bfs = dict(bfs)
#       3 print(bfs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/networkx/algorithms/traversal/breadth_first_search.py:298, in bfs_predecessors(G, source, depth_limit, sort_neighbors)
#     239 @nx._dispatch
#     240 def bfs_predecessors(G, source, depth_limit=None, sort_neighbors=None):
#     241     """Returns an iterator of predecessors in breadth-first-search from source.
#     242
#     243     Parameters
#    (...)
#     296     edge_bfs
#     297     """
# --> 298     for s, t in bfs_edges(
#     299         G, source, depth_limit=depth_limit, sort_neighbors=sort_neighbors
#     300     ):
#     301         yield (t, s)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/networkx/algorithms/traversal/breadth_first_search.py:170, in bfs_edges(G, source, reverse, depth_limit, sort_neighbors)
#     168 else:
#     169     successors = G.neighbors
# --> 170 yield from generic_bfs_edges(G, source, successors, depth_limit, sort_neighbors)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/networkx/algorithms/traversal/breadth_first_search.py:77, in generic_bfs_edges(G, source, neighbors, depth_limit, sort_neighbors)
#      75 if depth_limit is None:
#      76     depth_limit = len(G)
# ---> 77 queue = deque([(source, depth_limit, neighbors(source))])
#      78 while queue:
#      79     parent, depth_now, children = queue[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/networkx/classes/digraph.py:901, in DiGraph.successors(self, n)
#     899     return iter(self._succ[n])
#     900 except KeyError as err:
# --> 901     raise NetworkXError(f"The node {n} is not in the digraph.") from err
#
# NetworkXError: The node 0 is not in the digraph.

# %%
G = nx.path_graph(5)
dict(enumerate(nx.bfs_layers(G, [0, 4])))
H = nx.Graph()
H.add_edges_from([(0, 1), (0, 2), (1, 3), (1, 4), (2, 5), (2, 6)])
dict(enumerate(nx.bfs_layers(H, [1])))
dict(enumerate(nx.bfs_layers(H, [1, 6])))
# Out:
# {0: [1, 6], 1: [0, 3, 4, 2], 2: [5]}
